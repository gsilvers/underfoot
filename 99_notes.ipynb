# %% [markdown]
# # Underfoot Notes
#
# ## Assets While Developing
#
# ### 03 28 2021
#
# Today I'm working through tutorials on pygame. I do not think these assets will stay in game but I am using some assets from this free lib
#
# https://devilsworkshop.itch.io/low-poly-3d-and-pixel-2d-rpg-game-assets
